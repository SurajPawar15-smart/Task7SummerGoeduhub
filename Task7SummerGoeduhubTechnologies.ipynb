# %% [markdown]
# ***GO_STP_71: SURAJ SANJEEV PAWAR***

# %% [markdown]
# **Goeduhub Technologies**<br>
# ***https://www.goeduhub.com/***

# %% [markdown]
# **Assignment/Task 7**<br>
# ***Online Summer training on Machine Learning & Data Science With Python***

# %% [markdown]
# ***Prediction using Supervised Machine Learning using Simple Linear Regression.
# In this task we have to find the students scores based on their study hours. This is a simple Regression problem type because it has only two variables.***

# %%
from google.colab import files
from IPython import display

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4ecd9d42-d72c-4145-9b0d-1b4cd1c0c219" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ecd9d42-d72c-4145-9b0d-1b4cd1c0c219">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving supervised learning.jpg to supervised learning.jpg

# %%
display.Image("supervised learning.jpg")

# %% [markdown]
# ***Sample Dataset -->*** <br>
# https://drive.google.com/file/d/1vFumlk_XZAGKDtUOByWn_Ph-U797tVkO/view<br>
# ***you can download a csv file of dataset***

# %% [markdown]
# ***Supervised machine learningis a type of machine learning in which the machine is fed the training data which is labelled. Supervised machine learning is further categorized into regression and classification.***

# %% [markdown]
# ***Linear regression is probably the simplest approach for statistical learning. It is a good starting point for more advanced approaches, and in fact, many fancy statistical learning techniques can be seen as an extension of linear regression. Therefore, understanding this simple model will build a good base before moving on to more complex approaches.Output type- continuous (number)***

# %% [markdown]
# ###***Importing  required libraries***

# %%
#import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='drive/My Drive/'

# %% [markdown]
# ***1.Load the StudentHoursScores and read***

# %%
import pandas as pd
df=pd.read_csv(path+"/StudentHoursScores.csv")

# %% [markdown]
# ***to fine the type of the dataset***

# %%
#to find the type of dataset
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ***shape of the given dataset***

# %%
#to find the shape of dataframe
print(df.shape)
# Out:
# (23, 2)

# %% [markdown]
# ***Get the first five values form dataset***

# %%
#get the first top 5 values
df.head()
# Out:
#    Hours  Scores
# 0    7.7      79
# 1    5.9      60
# 2    4.5      45
# 3    3.3      33
# 4    1.1      12

# %% [markdown]
# ***Get the last five values form dataset***

# %%
#get the bottom 5 values
df.tail()
# Out:
#     Hours  Scores
# 18    9.6      96
# 19    4.3      42
# 20    4.1      40
# 21    3.0      30
# 22    2.6      25

# %% [markdown]
# ***find the correlation***

# %%
#to find the correlation in dataframe
df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.997656
# Scores  0.997656  1.000000

# %% [markdown]
# ***to find the columns name in dataset***

# %%
#to find the name of columns in dataframe
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %% [markdown]
# ***finding the min value in the dataset***

# %%
#to find the min on each column of the dataset
df.min()
# Out:
# Hours      1.1
# Scores    12.0
# dtype: float64

# %% [markdown]
# ***finding the max value in the dataset***

# %%
#to find the max on each column of the dataset
df.max()
# Out:
# Hours      9.6
# Scores    96.0
# dtype: float64

# %% [markdown]
# ***find any unique or dublicate value in dataset***

# %%
#to get info about the unique values in dataframe
df.nunique()
# Out:
# Hours     22
# Scores    22
# dtype: int64

# %% [markdown]
# ***slicing using iloc for integer number only***

# %%
#to get data using slicing using iloc 
df.iloc[2:8]
# Out:
#    Hours  Scores
# 2    4.5      45
# 3    3.3      33
# 4    1.1      12
# 5    8.9      87
# 6    2.5      21
# 7    1.9      19

# %% [markdown]
# ***Statistical Properties of Dataset***

# %%
#to summarize the statistical details of the dataframe
df.describe()
# Out:
#            Hours     Scores
# count  23.000000  23.000000
# mean    4.817391  47.695652
# std     2.709688  27.103228
# min     1.100000  12.000000
# 25%     2.650000  27.000000
# 50%     4.100000  40.000000
# 75%     7.100000  72.500000
# max     9.600000  96.000000

# %% [markdown]
# ***to summarize the dataset***

# %%
#to summarize the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   23 non-null     float64
#  1   Scores  23 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 496.0 bytes

# %% [markdown]
# ***to return the null value in dataset***

# %%
#to return the null values in the dataframe
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# ***Dataset is going to be divided into two parts dependent and independent variables or Diving Dataset into Features (inputs) and labels (outputs)***

# %%
## Splitting the dataset into Features and Label
X=df.iloc[:,:-1].values
y=df.iloc[:,1].values
print(X)
print(y)
# Out:
# [[7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [2.7]
#  [8.3]
#  [5.5]
#  [9.2]
#  [1.5]
#  [3.5]
#  [8.5]
#  [3.2]
#  [6.5]
#  [2.5]
#  [9.6]
#  [4.3]
#  [4.1]
#  [3. ]
#  [2.6]]
# [79 60 45 33 12 87 21 19 29 81 58 88 14 34 85 32 66 21 96 42 40 30 25]

# %% [markdown]
# ***Splitting the dataset into Training and Testing set***

# %%
#Splitting the dataset into Training-set and Testing-set
import sklearn
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
print("Shape of X_train",X_train.shape)
print("Shape of X_test",X_test.shape)
print("Shape of y_train",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of X_train (18, 1)
# Shape of X_test (5, 1)
# Shape of y_train (18,)
# Shape of y_test (5,)

# %% [markdown]
# ***Fitting Simple Linear Regression to the Training Dataset***

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ***Evaluation of model / Prediction of test Dataset***

# %%
# Predicting the values (Scores)
y_pred=model.predict(X_test)
y_pred
# Out:
# array([40.87711348, 25.025345  , 32.95122924, 34.9327003 , 42.85858454])

# %% [markdown]
# ***Observe the actual and predicting the output***

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})    
df1
# Out:
#    Actual  Predicted
# 0      40  40.877113
# 1      21  25.025345
# 2      33  32.951229
# 3      34  34.932700
# 4      42  42.858585

# %% [markdown]
# ***finding the mean squared error***

# %%
#Calculating Root Mean Squared Error
from sklearn.metrics import mean_squared_error, r2_score  
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 3.7164412473781487

# %% [markdown]
# ***Y= mx + c where m is a coefficient and c is intercept***

# %%
m=model.coef_
m
# Out:
# array([9.9073553])

# %%
c=model.intercept_
c
# Out:
# 0.2569567372371395

# %%
#Y= mx + c where m is a coefficient and c is intercept 
#Y=58.196585=9.90737*5.9-0.2569567372371395

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.3485028154894778
# Mean Squared Error: 3.7164412473781487
# Root Mean Squared Error: 1.927807367808866

# %% [markdown]
# ***Plotting for the training dataset***

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,model.predict(X_train),color='blue')
plt.title('Hours vs Scores(Training set)')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ***Plotting for the testing dataset***

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_test,y_test,color='red')
plt.plot(X_test,model.predict(X_test),color='blue')
plt.title('Hours vs Scores(Testing set)')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ***What will be predicted score if a student studies for 9.25 hrs/ day?***

# %%
#Predicting Score against 5.9 of Study Hours
h=5.9
s=model.predict([[h]])
print("If a student studies for {} hours per dayhe/She will Score {} % in exam.".format(h,s))
# Out:
# If a student studies for 5.9 hours per dayhe/She will Score [58.71035303] % in exam.

# %% [markdown]
# ***Thank you so much mam and Goeduhub Technologies***
